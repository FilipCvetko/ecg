# %%
import pandas as pd
import numpy as np
import wfdb
import ast
import scipy.signal as ss
import matplotlib.pyplot as plt
# %matplotlib inline
import heartpy as hp
from scipy.fft import fft, fftfreq, ifft
import time

# %%
path = ""
sampling_rate = 500

Y = pd.read_csv("ptbxl_database.csv", index_col=0)
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

num_patients = 21837
for i in range(22):
    for j in range(1000):
        i_temp = str(i).zfill(2)
        j_temp = str(j+1).zfill(3)
        data = wfdb.rdsamp(f"records500/000{i_temp}/00{j_temp}_hr")
        # Plotajmo drugi odvod
        x = np.linspace(0,2,5000)
        y = data[0][:5000, 6]
        plt.plot(x,y)
        plt.show()

plt.plot(x,y, "-")
plt.ylim((-1,1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-800d52d74286> in <module>
#      16         plt.plot(x,y)
#      17         plt.show()
# ---> 18         time.sleep(2)
#      19
#      20
#
# KeyboardInterrupt:
